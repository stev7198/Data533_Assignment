# %%
import unittest

from Test_teamstats_basic import TestBasic
from Test_teamstats_toplists import TestToplists

#testing for the Teamstats subpackage 

def my_suite():
    suite = unittest.TestSuite()
    result = unittest.TestResult()
    suite.addTest(TestBasic('test_BasicStats'))
    suite.addTest(TestBasic('test_AdvancedStats'))
    suite.addTest(TestToplists('test_TopTeams'))
    suite.addTest(TestToplists('test_TopAssists'))
    suite.addTest(TestToplists('test_TopGoals'))
    runner = unittest.TextTestRunner()
    print(runner.run(suite))
my_suite()
# Out:
# ----------------------------------------------------------------------
# Ran 0 tests in 0.000s
#
# OK
# test_AdvancedStats (Test_teamstats_basic.TestBasic.test_AdvancedStats)
# Test AdvancedStats ... /Users/tylerstevenson/Documents/MDS/Block 3/Data 533/Assignment/Data533_Assignment/hockey/teamstats/basic.py:17: DeprecationWarning: Use of .. or absolute path in a resource path is not allowed and will raise exceptions in a future release.
#   csv_path = pkg_resources.resource_stream(__name__, f"../{csv_filename}")
# /Users/tylerstevenson/Documents/MDS/Block 3/Data 533/Assignment/Data533_Assignment/hockey/teamstats/basic.py:47: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/tylerstevenson/Documents/MDS/Block 3/Data 533/Assignment/Data533_Assignment/hockey/teamstats/../Team2022.csv'>
#   df = LoadData() # calls the loadData function to get the correct year and dataframe
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# ok
# test_BasicStats (Test_teamstats_basic.TestBasic.test_BasicStats)
# Test BasicStats ... /Users/tylerstevenson/Documents/MDS/Block 3/Data 533/Assignment/Data533_Assignment/hockey/teamstats/basic.py:17: DeprecationWarning: Use of .. or absolute path in a resource path is not allowed and will raise exceptions in a future release.
#   csv_path = pkg_resources.resource_stream(__name__, f"../{csv_filename}")
# /Users/tylerstevenson/Documents/MDS/Block 3/Data 533/Assignment/Data533_Assignment/hockey/teamstats/basic.py:28: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/tylerstevenson/Documents/MDS/Block 3/Data 533/Assignment/Data533_Assignment/hockey/teamstats/../Team2022.csv'>
#   df = LoadData() # calls the loadData function to get the correct year and dataframe
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Users/tylerstevenson/Documents/MDS/Block 3/Data 533/Assignment/Data533_Assignment/hockey/teamstats/basic.py:17: DeprecationWarning: Use of .. or absolute path in a resource path is not allowed and will raise exceptions in a future release.
#   csv_path = pkg_resources.resource_stream(__name__, f"../{csv_filename}")
# /Users/tylerstevenson/Documents/MDS/Block 3/Data 533/Assignment/Data533_Assignment/hockey/teamstats/basic.py:28: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/tylerstevenson/Documents/MDS/Block 3/Data 533/Assignment/Data533_Assignment/hockey/teamstats/../Team2022.csv'>
#   df = LoadData() # calls the loadData function to get the correct year and dataframe
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.007s
#
# OK
# .....
# ----------------------------------------------------------------------
# Ran 5 tests in 0.067s
#
# OK
# setupClass
# Set Up
# Tear Down
# Set Up
# Tear Down
# teardownClass
# setupClass
# Set Up
# Tear Down
# Set Up
# Tear Down
# teardownClass
# setupClass
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# teardownClass
# <unittest.runner.TextTestResult run=5 errors=0 failures=0>

# %%
import unittest
from test_get_player_stats import TestGetUserInput
from test_player import TestPlayer 
from test_skater import TestSkater
from test_goalie import TestGoalie

#testing for the player subpackage

def player_suite():
    suite = unittest.TestSuite()
    
    # Add each test case method from the TestGetUserInput class to the suite
    suite.addTest(TestGetUserInput('test_get_player_stats_skater'))
    suite.addTest(TestGetUserInput('test_get_player_stats_goalie'))
    suite.addTest(TestGetUserInput('test_get_player_stats_invalid_player_type'))

    # Add each test case method from the TestPlayer class to the suite 
    suite.addTest(TestPlayer('test_initialization'))
    suite.addTest(TestPlayer('test_load_data_file_not_found'))
    suite.addTest(TestPlayer('test_get_player_data_found'))
    suite.addTest(TestPlayer('test_get_player_data_not_found'))

    # Add each test case method from the TestSkater class to the suite
    suite.addTest(TestSkater('test_initialization'))
    suite.addTest(TestSkater('test_load_data_file_not_found'))
    suite.addTest(TestSkater('test_basic_stats_found'))
    suite.addTest(TestSkater('test_basic_stats_not_found'))
    suite.addTest(TestSkater('test_advanced_stats_found'))
    suite.addTest(TestSkater('test_advanced_stats_not_found'))

    # Add each test case method from the TestGoalieclass to the suite
    suite.addTest(TestGoalie('test_initialization'))
    suite.addTest(TestGoalie('test_load_data_file_not_found'))
    suite.addTest(TestGoalie('test_basic_stats_found'))
    suite.addTest(TestGoalie('test_basic_stats_not_found'))
    suite.addTest(TestGoalie('test_advanced_stats_found'))
    suite.addTest(TestGoalie('test_advanced_stats_not_found'))
    
    # Run the test suite
    runner = unittest.TextTestRunner(verbosity=2)  # verbosity=2 gives more detailed output
    result = runner.run(suite)

# Run the suite
if __name__ == '__main__':
    player_suite()
# Out:
# test_get_player_stats_skater (test_get_player_stats.TestGetUserInput.test_get_player_stats_skater)
# Test the get_player_stats function for a skater (Evander Kane). ... ok
# test_get_player_stats_goalie (test_get_player_stats.TestGetUserInput.test_get_player_stats_goalie)
# Test the get_player_stats function for a goalie (Tristan Jarry). ... ok
# test_get_player_stats_invalid_player_type (test_get_player_stats.TestGetUserInput.test_get_player_stats_invalid_player_type)
# Test for invalid player type input. ... ok
# test_initialization (test_player.TestPlayer.test_initialization)
# Test the initialization of the Player class ... ok
# test_load_data_file_not_found (test_player.TestPlayer.test_load_data_file_not_found)
# Test the load_data method when the file is not found ... ok
# test_get_player_data_found (test_player.TestPlayer.test_get_player_data_found)
# Test the _get_player_data method when player data is found ... ok
# test_get_player_data_not_found (test_player.TestPlayer.test_get_player_data_not_found)
# Test the _get_player_data method when player data is not found ... ok
# test_initialization (test_skater.TestSkater.test_initialization)
# Test the initialization of the Skater class ... ok
# test_load_data_file_not_found (test_skater.TestSkater.test_load_data_file_not_found)
# Test the load_data method when the file is not found ... ok
# test_basic_stats_found (test_skater.TestSkater.test_basic_stats_found)
# Test the basic_stats method when the player data is found ... ok
# test_basic_stats_not_found (test_skater.TestSkater.test_basic_stats_not_found)
# Test the basic_stats method when the player is not found ... ok
# test_advanced_stats_found (test_skater.TestSkater.test_advanced_stats_found)
# Test the advanced_stats method when the player data is found ... ok
# test_advanced_stats_not_found (test_skater.TestSkater.test_advanced_stats_not_found)
# Test the advanced_stats method when the player is not found ... ok
# test_initialization (test_goalie.TestGoalie.test_initialization)
# Test the initialization of the Goalie class ... ok
# test_load_data_file_not_found (test_goalie.TestGoalie.test_load_data_file_not_found)
# Test the load_data method when the file is not found ... ok
# test_basic_stats_found (test_goalie.TestGoalie.test_basic_stats_found)
# Test the basic_stats method when the player data is found ... ok
# test_basic_stats_not_found (test_goalie.TestGoalie.test_basic_stats_not_found)
# Test the basic_stats method when the player is not found ...
# Setting up class resources.
# Setting up for a test.
# Tearing down after a test.
# Setting up for a test.
# Tearing down after a test.
# Setting up for a test.
# Tearing down after a test.
# Tearing down class resources.
# Setting up class resources.
# Tearing down after a test.
# Error: The file for the year 2023 was not found.
# Tearing down after a test.
# Tearing down after a test.
# Tearing down after a test.
# Tearing down class resources.
# Setting up class resources.
# Tearing down after a test.
# Error: The file for the year 2023 was not found.
# Tearing down after a test.
# Tearing down after a test.
# Tearing down after a test.
# Tearing down after a test.
# Tearing down after a test.
# Tearing down class resources.
# Setting up class resources.
# Tearing down after a test.
# Error: The file for the year 2023 was not found.
# Tearing down after a test.
# Tearing down after a test.
# Tearing down after a test.
# ok
# test_advanced_stats_found (test_goalie.TestGoalie.test_advanced_stats_found)
# Test the advanced_stats method when the player data is found ... ok
# test_advanced_stats_not_found (test_goalie.TestGoalie.test_advanced_stats_not_found)
# Test the advanced_stats method when the player is not found ... ok
#
# ----------------------------------------------------------------------
# Ran 19 tests in 0.192s
#
# OK
# Tearing down after a test.
# Tearing down after a test.
# Tearing down class resources.
